# %% [markdown]
# NOTE: At this point, focus is on getting predictions, and filling in placeholders in this notebook!

# %% [markdown]
# # P1 Milestone

# %% [markdown]
# ## Beginning of Baseline Model Performance:

# %%
# Installing Dependencies and or code for setting up virtual environment: 
# Necessary imports
# %uv pip install pandas 
# %uv pip install numpy 
# %uv pip install yfinance 
# Below is needed to get the real-time data
# %uv pip install datetime
# UPDATE: timedelta will be used to programmatically do the optimality algorithm. Refer to notes on timedelta class for reference.  
# %uv pip install pdb 
# %uv pip install scikit-learn
# End of Installing Dependencies and or code for setting up virtual environment:
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\adoct\AppData\Local\Programs\Python\Python312\python.exe: No module named uv
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\adoct\AppData\Local\Programs\Python\Python312\python.exe: No module named uv
# c:\Users\adoct\AppData\Local\Programs\Python\Python312\python.exe: No module named uv
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\adoct\AppData\Local\Programs\Python\Python312\python.exe: No module named uv
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\adoct\AppData\Local\Programs\Python\Python312\python.exe: No module named uv
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\adoct\AppData\Local\Programs\Python\Python312\python.exe: No module named uv
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\adoct\AppData\Local\Programs\Python\Python312\python.exe: No module named uv
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\adoct\AppData\Local\Programs\Python\Python312\python.exe: No module named uv
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\adoct\AppData\Local\Programs\Python\Python312\python.exe: No module named uv
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\adoct\AppData\Local\Programs\Python\Python312\python.exe: No module named uv
# c:\Users\adoct\AppData\Local\Programs\Python\Python312\python.exe: No module named uv
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# - Context: First we do the data preprocessing before it meets with the model[part a)]: [note, make habit to employ content-codeSnippet pairs!]

# %% [markdown]
# ### Beginning of Data Engineering Procedure

# %% [markdown]
# ### End of Data Engineering Procedure

# %% [markdown]
# #### Beginning of Model Development and Training Procedure

# %% [markdown]
# #### End of Model Development and Training Procedure

# %% [markdown]
# ### End of Baseline Model Performance:

# %% [markdown]
# - Context: Then we set up the model parameters[part b)]:
#
# [note, make habit to employ content-codeSnippet pairs!][UPDATE: Another idea could be running the full file first, to get the output, and then having team partition the rest of the files!]

# %% [markdown]
# ## End of Baseline Model Performance:

# %% [markdown]
# ## Experiment 1[Relationship between the Classifier Parameters(Precision and Recall)]
# ### Purpose
# - Setting up Classification problem and visualizing the model accuracy based on permutations of 2-tuple that references the Classifier/Model's parameters.
# ### Hypothesis
# - I believe that the tuple(s) of Classifiers parameters have no direct effect on the model's accuracy.

# %% [markdown]
# ### Instructions to Run
# Instructions: 1) Installing Dependencies in kernel environment, 2) Initiating Data Engineering Pipeline, 3) Setting up Model, 4) Using two situations where the 3-tupeles are different, 5) Comparing the results.

# %%
# Installing Dependencies and or code for setting up virtual environment: 
# Necessary imports
# %uv pip install pandas 
# %uv pip install numpy 
# %uv pip install yfinance 
# Below is needed to get the real-time data
# %uv pip install datetime
# UPDATE: timedelta will be used to programmatically do the optimality algorithm. Refer to notes on timedelta class for reference.  
# %uv pip install pdb 
# %uv pip install tensorflow 
# %uv pip install matplotlib
# from matplotlib import pyplot 
# %uv pip install pandas 
# %uv pip install numpy 
# %uv pip install pdb 
# %uv pip install tensorflow





# End of Installing Dependencies and or code for setting up virtual environment:
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\adoct\AppData\Local\Programs\Python\Python312\python.exe: No module named uv
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\adoct\AppData\Local\Programs\Python\Python312\python.exe: No module named uv
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\adoct\AppData\Local\Programs\Python\Python312\python.exe: No module named uv
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\adoct\AppData\Local\Programs\Python\Python312\python.exe: No module named uv
# c:\Users\adoct\AppData\Local\Programs\Python\Python312\python.exe: No module named uv
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\adoct\AppData\Local\Programs\Python\Python312\python.exe: No module named uv
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\adoct\AppData\Local\Programs\Python\Python312\python.exe: No module named uv
# c:\Users\adoct\AppData\Local\Programs\Python\Python312\python.exe: No module named uv
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\adoct\AppData\Local\Programs\Python\Python312\python.exe: No module named uv
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\adoct\AppData\Local\Programs\Python\Python312\python.exe: No module named uv
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\adoct\AppData\Local\Programs\Python\Python312\python.exe: No module named uv

# %% [markdown]
# - Context: First we do the data preprocessing before it meets with the model[part a)]: [note, make habit to employ content-codeSnippet pairs!]

# %% [markdown]
# ### Beginning of Data Engineering Procedure

# %% [markdown]
# ### End of Data Engineering Procedure

# %% [markdown]
# #### Beginning of Model Development and Training Procedure

# %% [markdown]
# #### Testing out tuple (5,45) of network parameters

# %% [markdown]
# #### End of Testing out tuple (5,45) of network parameters

# %% [markdown]
# #### Testing out tuple (5,30) of network parameters

# %% [markdown]
# #### End of Testing out tuple (5,30) of network parameters

# %% [markdown]
# #### End of Model Development and Training Procedure

# %% [markdown]
# - Context: Then we set up the model parameters[part b)]:
#
# [note, make habit to employ content-codeSnippet pairs!][UPDATE: Another idea could be running the full file first, to get the output, and then having team partition the rest of the files!]

# %% [markdown]
# - Context: Then we set up the model parameters[part b)]:
#
# [note, make habit to employ content-codeSnippet pairs!][UPDATE: Another idea could be running the full file first, to get the output, and then having team partition the rest of the files!]

# %% [markdown]
# ### Results
# - As expressed in the graphs above, it is evident (cont here)

# %% [markdown]
# ### Conclusion
# - As expressed, it is evident that (cont here)
